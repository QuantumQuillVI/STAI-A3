# %%
import json
from sklearn.metrics import cohen_kappa_score
from sklearn.preprocessing import MultiLabelBinarizer

# %% [markdown]
# ## ASSIGNMENT TASK 3 : INTER ANNOTATOR AGREEMENT
#
# Task 3: Implementing Inter-Annotator Agreement
# Export the annotations in either JSON or CSV files.
# Using Pyt hon code, calculate Cohen’s Kappa & Fleiss Kappa.
# Use Cohen’s Kappa for the NLP Dataset Task.
# Use Fleiss Kappa for the CV Dataset Task. Get the third annotation from any other teams and then calculate the Fleiss Kappa.
# Output the agreement score and interpret its significance.

# %% [markdown]
# ---
# # Cohen's Kappa for NLP Annotations

# %%
def load_annotations1(file_path):
    """
    this function loads annotations from a JSON file, extract and sorts POS tags by "start".

    Parameters:
        file_path (str): Path to the JSON file.

    Returns:
        pos_tags (list): List of lists containing POS tags for each sentence.
        data (list): List of the original data with sorted POS tags.
    """
    import json

    with open(file_path, "r") as file:
        data = json.load(file)  # Load the JSON file

    pos_tags = []
    for item in data:
        if "pos" in item:  # Check if the key "pos" exists
            # Sort the "pos" list by the "start" field
            item["pos"].sort(key=lambda x: x["start"])

            # Extract the POS tags after sorting
            tags = [pos["labels"][0] for pos in item["pos"]]
            pos_tags.append(tags)
        else:
            print(f"Skipping item with missing 'pos' key: {item}")

    return pos_tags


def load_annotations2(file_path):
    """
    Load annotations from a JSON file, extract and sort POS tags by "start".

    Parameters:
        file_path (str): Path to the JSON file.

    Returns:
        pos_tags (list): List of lists containing POS tags for each sentence.
        data (list): List of the original data with sorted POS tags.
    """
    import json

    with open(file_path, "r") as file:
        data = json.load(file)  # Load the JSON file

    pos_tags = []
    for item in data:
        if "label" in item:  # Check if the key "pos" exists
            # Sort the "pos" list by the "start" field
            item["label"].sort(key=lambda x: x["start"])

            # Extract the POS tags after sorting
            tags = [label["labels"][0] for label in item["label"]]
            pos_tags.append(tags)
        else:
            print(f"Skipping item with missing 'pos' key: {item}")

    return pos_tags




def align_annotations(annotator1_data, annotator2_data):
    """
    Align the POS tags of two annotators for comparison.
    Assumes both annotators annotate the same data points in the same order.
    """
    aligned_annotator1 = []
    aligned_annotator2 = []
    for tags1, tags2 in zip(annotator1_data, annotator2_data):
        min_len = min(len(tags1), len(tags2))  # Handle differing tag lengths
        aligned_annotator1.extend(tags1[:min_len])
        aligned_annotator2.extend(tags2[:min_len])
    return aligned_annotator1, aligned_annotator2



def calculate_cohens_kappa(annotator1_tags, annotator2_tags):
    """
    Calculate Cohen's Kappa score between two annotators' POS tag sequences.

    Parameters:
        annotator1_tags (list of lists): POS tags from Annotator 1.
        annotator2_tags (list of lists): POS tags from Annotator 2.

    Returns:
        float: Cohen's Kappa score.
    """
    # Ensure both annotators have the same number of sentences
    if len(annotator1_tags) != len(annotator2_tags):
        raise ValueError("Annotator data lengths do not match!")

    # Calculate Cohen's Kappa score
    kappa = cohen_kappa_score(annotator1_tags, annotator2_tags)

    return kappa

# %%
# File paths for the two annotators
annotator1_file = "/content/NLP-TEAM2 - OM.json"
annotator2_file = "/content/NLP-TEAM2-PRANAV.json"
# Load annotations
annotator1_data = load_annotations1(annotator1_file)
annotator2_data = load_annotations2(annotator2_file)

# %%
aligned_annotator1, aligned_annotator2 = align_annotations(annotator1_data, annotator2_data)

# %%
for i in range(len(aligned_annotator1)):
  print(f'tag no. : {i} ----> {aligned_annotator1[i]}   :    {aligned_annotator2[i]}')        # Aligned tags for both the annotatora=s have been printed against each other
# Out:
# tag no. : 0 ----> X   :    X
# tag no. : 1 ----> PROPN   :    PROPN
# tag no. : 2 ----> ADP   :    PRON
# tag no. : 3 ----> NOUN   :    NOUN
# tag no. : 4 ----> ADP   :    PROPN
# tag no. : 5 ----> PROPN   :    PRON
# tag no. : 6 ----> ADP   :    NOUN
# tag no. : 7 ----> NOUN   :    X
# tag no. : 8 ----> X   :    X
# tag no. : 9 ----> X   :    PROPN
# tag no. : 10 ----> PROPN   :    X
# tag no. : 11 ----> X   :    PROPN
# tag no. : 12 ----> PROPN   :    X
# tag no. : 13 ----> PROPN   :    PROPN
# tag no. : 14 ----> X   :    X
# tag no. : 15 ----> PROPN   :    NOUN
# tag no. : 16 ----> PROPN   :    PROPN
# tag no. : 17 ----> ADP   :    NOUN
# tag no. : 18 ----> NOUN   :    NOUN
# tag no. : 19 ----> X   :    X
# tag no. : 20 ----> PROPN   :    PROPN
# tag no. : 21 ----> PROPN   :    PROPN
# tag no. : 22 ----> CONJ   :    CONJ
# tag no. : 23 ----> PROPN   :    PROPN
# tag no. : 24 ----> PROPN   :    PROPN
# tag no. : 25 ----> ADP   :    PRON
# tag no. : 26 ----> ADV   :    ADJ
# tag no. : 27 ----> PROPN   :    PROPN
# tag no. : 28 ----> X   :    X
# tag no. : 29 ----> PROPN   :    PROPN
# tag no. : 30 ----> PROPN   :    PROPN
# tag no. : 31 ----> PROPN   :    PROPN
# tag no. : 32 ----> PROPN   :    PROPN
# tag no. : 33 ----> PROPN   :    PROPN
# tag no. : 34 ----> PROPN   :    PROPN
# tag no. : 35 ----> ADP   :    PRON
# tag no. : 36 ----> PROPN   :    PROPN
# tag no. : 37 ----> PROPN   :    PROPN
# tag no. : 38 ----> ADP   :    ADP
# tag no. : 39 ----> VERB   :    VERB
# tag no. : 40 ----> NOUN   :    NUM
# tag no. : 41 ----> VERB   :    NOUN
# tag no. : 42 ----> NOUN   :    NOUN
# tag no. : 43 ----> ADP   :    PRON
# tag no. : 44 ----> NOUN   :    NOUN
# tag no. : 45 ----> X   :    X
# tag no. : 46 ----> ADJ   :    ADJ
# tag no. : 47 ----> NOUN   :    VERB
# tag no. : 48 ----> X   :    X
# tag no. : 49 ----> PROPN   :    PROPN
# tag no. : 50 ----> X   :    X
# tag no. : 51 ----> PROPN   :    PROPN
# tag no. : 52 ----> PROPN   :    PROPN
# tag no. : 53 ----> PROPN   :    PROPN
# tag no. : 54 ----> ADP   :    PRON
# tag no. : 55 ----> PROPN   :    PROPN
# tag no. : 56 ----> ADP   :    PRON
# tag no. : 57 ----> ADV   :    NOUN
# tag no. : 58 ----> NOUN   :    PRON
# tag no. : 59 ----> ADP   :    NOUN
# tag no. : 60 ----> NOUN   :    PRON
# tag no. : 61 ----> ADP   :    VERB
# tag no. : 62 ----> VERB   :    VERB
# tag no. : 63 ----> NOUN   :    X
# tag no. : 64 ----> X   :    PROPN
# tag no. : 65 ----> PROPN   :    PROPN
# tag no. : 66 ----> PROPN   :    PROPN
# tag no. : 67 ----> NOUN   :    NOUN
# tag no. : 68 ----> NOUN   :    X
# tag no. : 69 ----> X   :    PROPN
# tag no. : 70 ----> PROPN   :    PROPN
# tag no. : 71 ----> PROPN   :    PROPN
# tag no. : 72 ----> PROPN   :    PROPN
# tag no. : 73 ----> PROPN   :    PROPN
# tag no. : 74 ----> ADP   :    PRON
# tag no. : 75 ----> ADP   :    ADV
# tag no. : 76 ----> PROPN   :    PROPN
# tag no. : 77 ----> PROPN   :    PROPN
# tag no. : 78 ----> PROPN   :    NOUN
# tag no. : 79 ----> ADP   :    NOUN
# tag no. : 80 ----> PRON_WH   :    NOUN
# tag no. : 81 ----> VERB   :    ADP
# tag no. : 82 ----> X   :    PRON_WH
# tag no. : 83 ----> X   :    VERB
# tag no. : 84 ----> PROPN   :    X
# tag no. : 85 ----> PROPN   :    X
# tag no. : 86 ----> PROPN   :    PROPN
# tag no. : 87 ----> ADV   :    PROPN
# tag no. : 88 ----> NOUN   :    PROPN
# tag no. : 89 ----> PROPN   :    PROPN
# tag no. : 90 ----> PROPN   :    PROPN
# tag no. : 91 ----> PROPN   :    PROPN
# tag no. : 92 ----> ADJ   :    ADJ
# tag no. : 93 ----> NOUN   :    NOUN
# tag no. : 94 ----> X   :    X
# tag no. : 95 ----> PROPN   :    PROPN
# tag no. : 96 ----> ADP   :    PRON
# tag no. : 97 ----> VERB   :    VERB
# tag no. : 98 ----> PROPN   :    PROPN
# tag no. : 99 ----> X   :    X
# tag no. : 100 ----> NOUN   :    NOUN
# tag no. : 101 ----> ADP   :    ADP
# tag no. : 102 ----> PROPN   :    PROPN
# tag no. : 103 ----> NOUN   :    NOUN
# tag no. : 104 ----> X   :    X
# tag no. : 105 ----> PROPN   :    PROPN
# tag no. : 106 ----> X   :    X
# tag no. : 107 ----> PROPN   :    PROPN
# tag no. : 108 ----> ADP   :    PRON
# tag no. : 109 ----> NOUN   :    NOUN
# tag no. : 110 ----> ADP   :    PRON
# tag no. : 111 ----> ADP   :    ADJ
# tag no. : 112 ----> X   :    X
# tag no. : 113 ----> PROPN   :    PROPN
# tag no. : 114 ----> ADP   :    PRON
# tag no. : 115 ----> ADP   :    ADP
# tag no. : 116 ----> PROPN   :    PROPN
# tag no. : 117 ----> ADP   :    PRON
# tag no. : 118 ----> ADJ   :    ADJ
# tag no. : 119 ----> NOUN   :    VERB
# tag no. : 120 ----> X   :    X
# tag no. : 121 ----> X   :    X
# tag no. : 122 ----> X   :    X
# tag no. : 123 ----> PROPN   :    PROPN
# tag no. : 124 ----> X   :    X
# tag no. : 125 ----> PROPN   :    X
# tag no. : 126 ----> X   :    X
# tag no. : 127 ----> PROPN   :    PROPN
# tag no. : 128 ----> NOUN   :    NOUN
# tag no. : 129 ----> ADP   :    PRON
# tag no. : 130 ----> NOUN   :    ADV
# tag no. : 131 ----> X   :    X
# tag no. : 132 ----> PROPN   :    PROPN
# tag no. : 133 ----> ADP   :    PRON
# tag no. : 134 ----> X   :    X
# tag no. : 135 ----> PROPN   :    PROPN
# tag no. : 136 ----> ADP   :    PRON
# tag no. : 137 ----> VERB   :    VERB
# tag no. : 138 ----> PRON   :    ADV
# tag no. : 139 ----> ADJ   :    ADV
# tag no. : 140 ----> NOUN   :    ADV
# tag no. : 141 ----> X   :    ADJ
# tag no. : 142 ----> X   :    NOUN
# tag no. : 143 ----> PROPN   :    X
# tag no. : 144 ----> X   :    X
# tag no. : 145 ----> PROPN   :    PROPN
# tag no. : 146 ----> X   :    X
# tag no. : 147 ----> PROPN   :    PROPN
# tag no. : 148 ----> PROPN   :    PROPN
# tag no. : 149 ----> NOUN   :    NOUN
# tag no. : 150 ----> VERB   :    VERB
# tag no. : 151 ----> ADP   :    PRON
# tag no. : 152 ----> ADV   :    ADV
# tag no. : 153 ----> PROPN   :    PROPN
# tag no. : 154 ----> PROPN   :    PROPN
# tag no. : 155 ----> PROPN   :    PROPN
# tag no. : 156 ----> ADP   :    PRON
# tag no. : 157 ----> PROPN   :    NOUN
# tag no. : 158 ----> NOUN   :    VERB
# tag no. : 159 ----> X   :    X
# tag no. : 160 ----> PROPN   :    PROPN
# tag no. : 161 ----> CONJ   :    CONJ
# tag no. : 162 ----> PROPN   :    PROPN
# tag no. : 163 ----> X   :    X
# tag no. : 164 ----> PROPN   :    PROPN
# tag no. : 165 ----> PROPN   :    PROPN
# tag no. : 166 ----> PROPN   :    NOUN
# tag no. : 167 ----> VERB   :    VERB
# tag no. : 168 ----> ADP   :    ADP
# tag no. : 169 ----> ADV   :    ADV
# tag no. : 170 ----> PROPN   :    PROPN
# tag no. : 171 ----> PROPN   :    PROPN
# tag no. : 172 ----> PROPN   :    PROPN
# tag no. : 173 ----> ADP   :    PRON
# tag no. : 174 ----> ADJ   :    ADJ
# tag no. : 175 ----> NOUN   :    NOUN
# tag no. : 176 ----> NOUN   :    NOUN
# tag no. : 177 ----> X   :    X
# tag no. : 178 ----> PROPN   :    PROPN
# tag no. : 179 ----> CONJ   :    CONJ
# tag no. : 180 ----> PROPN   :    PROPN
# tag no. : 181 ----> X   :    X
# tag no. : 182 ----> PROPN   :    PROPN
# tag no. : 183 ----> PRON   :    ADP
# tag no. : 184 ----> NOUN   :    NOUN
# tag no. : 185 ----> ADP   :    PRON
# tag no. : 186 ----> PROPN   :    PROPN
# tag no. : 187 ----> ADP   :    PRON
# tag no. : 188 ----> ADJ   :    ADJ
# tag no. : 189 ----> NOUN   :    NOUN
# tag no. : 190 ----> ADV   :    ADP
# tag no. : 191 ----> VERB   :    VERB
# tag no. : 192 ----> VERB   :    VERB
# tag no. : 193 ----> X   :    X
# tag no. : 194 ----> PROPN   :    PROPN
# tag no. : 195 ----> PROPN   :    PROPN
# tag no. : 196 ----> PROPN   :    PROPN
# tag no. : 197 ----> ADP   :    PRON
# tag no. : 198 ----> PROPN   :    PROPN
# tag no. : 199 ----> ADP   :    PRON
# tag no. : 200 ----> VERB   :    VERB
# tag no. : 201 ----> NOUN   :    VERB
# tag no. : 202 ----> X   :    X
# tag no. : 203 ----> PROPN   :    PROPN
# tag no. : 204 ----> PROPN   :    PROPN
# tag no. : 205 ----> PROPN   :    PROPN
# tag no. : 206 ----> ADP   :    PRON
# tag no. : 207 ----> NOUN   :    NOUN
# tag no. : 208 ----> VERB   :    VERB
# tag no. : 209 ----> X   :    X
# tag no. : 210 ----> PROPN   :    PROPN
# tag no. : 211 ----> PROPN   :    PROPN
# tag no. : 212 ----> NOUN   :    NOUN
# tag no. : 213 ----> NOUN   :    NOUN
# tag no. : 214 ----> X   :    X
# tag no. : 215 ----> PROPN   :    PROPN
# tag no. : 216 ----> PROPN   :    PROPN
# tag no. : 217 ----> PROPN   :    X
# tag no. : 218 ----> X   :    PROPN
# tag no. : 219 ----> PROPN   :    X
# tag no. : 220 ----> PROPN   :    PROPN
# tag no. : 221 ----> PROPN   :    PROPN
# tag no. : 222 ----> PROPN   :    PROPN
# tag no. : 223 ----> PROPN   :    PROPN
# tag no. : 224 ----> ADP   :    PRON
# tag no. : 225 ----> PROPN   :    PROPN
# tag no. : 226 ----> ADP   :    PRON
# tag no. : 227 ----> VERB   :    VERB
# tag no. : 228 ----> NOUN   :    NOUN
# tag no. : 229 ----> ADV   :    CONJ
# tag no. : 230 ----> VERB   :    CONJ
# tag no. : 231 ----> NOUN   :    VERB
# tag no. : 232 ----> X   :    VERB
# tag no. : 233 ----> PROPN   :    X
# tag no. : 234 ----> PROPN   :    PROPN
# tag no. : 235 ----> X   :    PROPN
# tag no. : 236 ----> PROPN   :    X
# tag no. : 237 ----> PROPN   :    PROPN
# tag no. : 238 ----> X   :    PROPN
# tag no. : 239 ----> PROPN   :    X
# tag no. : 240 ----> PROPN   :    PROPN
# tag no. : 241 ----> PROPN   :    PROPN
# tag no. : 242 ----> NOUN   :    NOUN
# tag no. : 243 ----> ADP   :    ADP
# tag no. : 244 ----> PROPN   :    PROPN
# tag no. : 245 ----> PROPN   :    PROPN
# tag no. : 246 ----> ADP   :    PRON
# tag no. : 247 ----> NOUN   :    VERB
# tag no. : 248 ----> X   :    X
# tag no. : 249 ----> ADJ   :    ADJ
# tag no. : 250 ----> NOUN   :    NOUN
# tag no. : 251 ----> NOUN   :    NOUN
# tag no. : 252 ----> X   :    X
# tag no. : 253 ----> PROPN   :    PROPN
# tag no. : 254 ----> PROPN   :    PROPN
# tag no. : 255 ----> X   :    X
# tag no. : 256 ----> PROPN   :    PROPN
# tag no. : 257 ----> PROPN   :    PROPN
# tag no. : 258 ----> PROPN   :    PROPN
# tag no. : 259 ----> PROPN   :    PROPN
# tag no. : 260 ----> PROPN   :    NOUN
# tag no. : 261 ----> VERB   :    VERB
# tag no. : 262 ----> ADP   :    ADP
# tag no. : 263 ----> PROPN   :    PROPN
# tag no. : 264 ----> ADP   :    PRON
# tag no. : 265 ----> PROPN   :    PROPN
# tag no. : 266 ----> PROPN   :    PROPN
# tag no. : 267 ----> ADP   :    PRON
# tag no. : 268 ----> NOUN   :    NOUN
# tag no. : 269 ----> X   :    X
# tag no. : 270 ----> X   :    X
# tag no. : 271 ----> X   :    X
# tag no. : 272 ----> PROPN   :    PROPN
# tag no. : 273 ----> X   :    X
# tag no. : 274 ----> PROPN   :    PROPN
# tag no. : 275 ----> X   :    X
# tag no. : 276 ----> PROPN   :    PROPN
# tag no. : 277 ----> X   :    X
# tag no. : 278 ----> PROPN   :    NOUN
# tag no. : 279 ----> X   :    X
# tag no. : 280 ----> PROPN   :    PROPN
# tag no. : 281 ----> ADP   :    PRON
# tag no. : 282 ----> NOUN   :    NOUN
# tag no. : 283 ----> PROPN   :    PROPN
# tag no. : 284 ----> ADP   :    ADP
# tag no. : 285 ----> VERB   :    VERB
# tag no. : 286 ----> ADV   :    VERB
# tag no. : 287 ----> X   :    X
# tag no. : 288 ----> X   :    X
# tag no. : 289 ----> PROPN   :    PROPN
# tag no. : 290 ----> ADP   :    PRON
# tag no. : 291 ----> NOUN   :    NOUN
# tag no. : 292 ----> NOUN   :    NOUN
# tag no. : 293 ----> ADP   :    ADP
# tag no. : 294 ----> VERB   :    VERB
# tag no. : 295 ----> ADV   :    VERB
# tag no. : 296 ----> X   :    X
# tag no. : 297 ----> PROPN   :    PROPN
# tag no. : 298 ----> PROPN   :    PROPN
# tag no. : 299 ----> PROPN   :    PROPN
# tag no. : 300 ----> ADP   :    PRON
# tag no. : 301 ----> PROPN   :    PROPN
# tag no. : 302 ----> ADP   :    PRON
# tag no. : 303 ----> NOUN   :    NOUN
# tag no. : 304 ----> VERB   :    VERB
# tag no. : 305 ----> ADP   :    ADP
# tag no. : 306 ----> PROPN   :    PROPN
# tag no. : 307 ----> ADP   :    PRON
# tag no. : 308 ----> PROPN   :    PROPN
# tag no. : 309 ----> ADP   :    PRON
# tag no. : 310 ----> VERB   :    VERB
# tag no. : 311 ----> ADJ   :    ADJ
# tag no. : 312 ----> NOUN   :    NOUN
# tag no. : 313 ----> X   :    X
# tag no. : 314 ----> PROPN   :    PROPN
# tag no. : 315 ----> CONJ   :    CONJ
# tag no. : 316 ----> PROPN   :    PROPN
# tag no. : 317 ----> PROPN   :    PROPN
# tag no. : 318 ----> PROPN   :    PROPN
# tag no. : 319 ----> ADP   :    ADP
# tag no. : 320 ----> PROPN   :    PROPN
# tag no. : 321 ----> ADP   :    PRON
# tag no. : 322 ----> PROPN   :    PROPN
# tag no. : 323 ----> PROPN   :    PROPN
# tag no. : 324 ----> ADP   :    NOUN
# tag no. : 325 ----> PROPN   :    ADP
# tag no. : 326 ----> PROPN   :    PROPN
# tag no. : 327 ----> PROPN   :    PROPN
# tag no. : 328 ----> ADP   :    NOUN
# tag no. : 329 ----> ADJ   :    NOUN
# tag no. : 330 ----> NOUN   :    PRON
# tag no. : 331 ----> X   :    ADJ
# tag no. : 332 ----> PROPN   :    VERB
# tag no. : 333 ----> PROPN   :    PROPN
# tag no. : 334 ----> PROPN   :    PROPN
# tag no. : 335 ----> PROPN   :    PROPN
# tag no. : 336 ----> ADP   :    ADP
# tag no. : 337 ----> PROPN   :    PROPN
# tag no. : 338 ----> PROPN   :    PROPN
# tag no. : 339 ----> ADP   :    PRON
# tag no. : 340 ----> ADJ   :    ADJ
# tag no. : 341 ----> NOUN   :    NOUN
# tag no. : 342 ----> X   :    X
# tag no. : 343 ----> X   :    X
# tag no. : 344 ----> PROPN   :    PROPN
# tag no. : 345 ----> PROPN   :    PROPN
# tag no. : 346 ----> X   :    X
# tag no. : 347 ----> NOUN   :    NOUN
# tag no. : 348 ----> ADP   :    ADP
# tag no. : 349 ----> PROPN   :    PROPN
# tag no. : 350 ----> X   :    X
# tag no. : 351 ----> PROPN   :    PROPN
# tag no. : 352 ----> PROPN   :    PROPN
# tag no. : 353 ----> ADP   :    PRON
# tag no. : 354 ----> NOUN   :    VERB
# tag no. : 355 ----> ADP   :    ADP
# tag no. : 356 ----> ADJ   :    ADJ
# tag no. : 357 ----> NOUN   :    VERB
# tag no. : 358 ----> X   :    X
# tag no. : 359 ----> X   :    X
# tag no. : 360 ----> PROPN   :    PROPN
# tag no. : 361 ----> PROPN   :    PROPN
# tag no. : 362 ----> ADP   :    PRON
# tag no. : 363 ----> PROPN   :    PROPN
# tag no. : 364 ----> ADP   :    PRON
# tag no. : 365 ----> PROPN   :    PROPN
# tag no. : 366 ----> ADP   :    PRON
# tag no. : 367 ----> ADV   :    VERB
# tag no. : 368 ----> VERB   :    VERB

# %%
#Calculating the score
kappa_score = calculate_cohens_kappa(aligned_annotator1, aligned_annotator2)

# Output the result
print(f"Cohen's Kappa Score: {kappa_score:.4f}")
if kappa_score > 0.8:
    interpretation = "Almost Perfect Agreement"
elif kappa_score > 0.6:
    interpretation = "Substantial Agreement"
elif kappa_score > 0.4:
    interpretation = "Moderate Agreement"
elif kappa_score > 0.2:
    interpretation = "Fair Agreement"
elif kappa_score > 0:
    interpretation = "Slight Agreement"
else:
    interpretation = "No Agreement"

print(f"Interpretation: {interpretation}")
# Out:
# Cohen's Kappa Score: 0.5991
# Interpretation: Moderate Agreement

# %% [markdown]
# ---
# The obtained Cohen’s Kappa score is 0.5991, which falls into the moderate agreement category,
#
# A score of 0.5991 indicates that there is a moderate level
# of agreement between the two raters or models. In other words, while the two models or raters do agree on the categorization of the data fairly often, they also have some level of disagreement.

# %% [markdown]
# ---
#
# # Fleiss's Kappa for CV Annotations

# %%
import json
import numpy as np
from statsmodels.stats.inter_rater import fleiss_kappa
from collections import defaultdict
import statsmodels

# %%
import json
import numpy as np

# Load all the json files (assuming the files are named file1.json, file2.json, file3.json)
files = ['/content/CV-TEAM2-PRANAV.json', '/content/CV-TEAM2-OM.json', '/content/CV-TEAM2-3.json']


def fleiss_kappa_score(files):

    # Data structure to hold the results
    annotations = []

    # Iterates through each file and collect the annotations
    for idx, file in enumerate(files):
        img_id = []
        annote = []
        with open(file, 'r') as f:
            data = json.load(f)
            annotator = idx + 1  # Annotator number starts from 1
            for entry in data:
                classification = entry["choice"]
                annote.append(classification)
                img_id.append(entry["image"])
        annotations.append (annote)
    for i in range(len(annote)) :
        print(f'{img_id[i]}---> ann1:{annotations[0][i]},  ann2:{annotations[1][i]},  ann3:{annotations[2][i]}')
        ## This part loads the annotations files from three annotators and creates
        ## a 2-D array containing category assignment with subjects in rows and raters in columns.
    table = statsmodels.stats.inter_rater.aggregate_raters(annotations)
    ## function to convert the 2-D array into a compatible format for the fleiss kappa calculator function
    print(table)
    score = statsmodels.stats.inter_rater.fleiss_kappa(table[0], method='fleiss')
    ## This calculates the fleiss kappa score
    return score

# %%
score = fleiss_kappa_score(files)
# Out:
# /data/upload/5/bde75fcc-img_20.jpg---> ann1:No Truck,  ann2:No Truck,  ann3:No Truck
# /data/upload/5/f3565be8-img_21.jpg---> ann1:No Truck,  ann2:No Truck,  ann3:Truck
# /data/upload/5/fef703fc-img_22.jpg---> ann1:No Truck,  ann2:No Truck,  ann3:No Truck
# /data/upload/5/c2c304f9-img_23.jpg---> ann1:No Truck,  ann2:No Truck,  ann3:No Truck
# /data/upload/5/23489a8b-img_24.jpg---> ann1:No Truck,  ann2:Truck,  ann3:No Truck
# /data/upload/5/0fe71ede-img_25.jpg---> ann1:No Truck,  ann2:No Truck,  ann3:No Truck
# /data/upload/5/01c5ba37-img_26.jpg---> ann1:Truck,  ann2:Truck,  ann3:Truck
# /data/upload/5/3143fd82-img_27.jpg---> ann1:Truck,  ann2:Truck,  ann3:Truck
# /data/upload/5/344f540d-img_28.jpg---> ann1:No Truck,  ann2:No Truck,  ann3:No Truck
# /data/upload/5/05703423-img_29.jpg---> ann1:Truck,  ann2:Truck,  ann3:Truck
# /data/upload/5/d76e87d3-img_30.jpg---> ann1:No Truck,  ann2:Truck,  ann3:Truck
# /data/upload/5/d92ba013-img_31.jpg---> ann1:No Truck,  ann2:Truck,  ann3:No Truck
# /data/upload/5/9738303f-img_32.jpg---> ann1:No Truck,  ann2:Truck,  ann3:No Truck
# /data/upload/5/9b20428d-img_33.jpg---> ann1:Truck,  ann2:Truck,  ann3:No Truck
# /data/upload/5/ef7a2bdc-img_34.jpg---> ann1:No Truck,  ann2:No Truck,  ann3:Truck
# /data/upload/5/494d5390-img_35.jpg---> ann1:No Truck,  ann2:No Truck,  ann3:No Truck
# /data/upload/5/525e29b2-img_36.jpg---> ann1:Truck,  ann2:Truck,  ann3:Truck
# /data/upload/5/a255b1c9-img_37.jpg---> ann1:Truck,  ann2:Truck,  ann3:Truck
# /data/upload/5/53e198b8-img_38.jpg---> ann1:Truck,  ann2:Truck,  ann3:No Truck
# /data/upload/5/945fef75-img_39.jpg---> ann1:Truck,  ann2:Truck,  ann3:No Truck
# (array([[12,  8],
#        [ 8, 12],
#        [12,  8]]), array(['No Truck', 'Truck'], dtype='<U8'))

# %%
print(f'Fleiss kappa Score =  {score}')
# Out:
# Fleiss kappa Score =  -0.015037593984962468

# %% [markdown]
# ---
# The Fleiss' Kappa score of -0.0150 indicates poor agreement between the raters, even worse than what would be expected by chance. This negative value suggests that the raters are consistently in disagreement, possibly due to unclear or ambiguous categories, inconsistent raters, or a flawed classification system. In this case, the score indicates a need for revising the categorization process, improving rater consistency, or addressing issues with the quality of the data to ensure better agreement.
#
#
# ---
#
# ---
